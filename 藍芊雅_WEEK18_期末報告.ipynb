# %% [markdown]
# <a href="https://colab.research.google.com/github/A106240272/computational-thingking-and-program-desigpn/blob/main/%E8%97%8D%E8%8A%8A%E9%9B%85_WEEK18_%E6%9C%9F%E6%9C%AB%E5%A0%B1%E5%91%8A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 期末分組報告: 配對機器人
##組員:廖偲嘉,張菱恩,陳意捷,藍芊雅
## ver1.0 : 此版本只服務單身女性
## 問題與回答皆可以選擇,沒有限制
## 2021/06/23

#簡單問候
print("嗨！你好我是配對機器人,")
print("在現今的社會中,大部分的人都忙碌於自己的工作或課業,沒有時間或機會找到自己的Mr.Right")
print("如果你也有這方面的困擾,找我就對了!")

#是否有合適的對象?(如已有合適對象,將不提供服務)
print("首先,我想了解一個基本問題")
question1 = input("還沒有合適的對象嗎？yes or no:")
if question1 == "no":
  print("抱歉! 請珍惜現有的感情, 你不是我們服務的對象喔!")

else:
  print("歡迎參加我們的活動,")
  print("很高興在此為您服務!")
  name = input("請告訴我你的名字:")
  print(f"你好{name}，很高興認識你！")
  print("我能為你找到比陽光還熱情的另一半，也能在寒冷的冬天時，為你尋找溫暖的另一半。")
  print("透過活動，我將層層配對與你性格相合的人，不必再為牙膏要擠前面還是後面困擾了！")
  print("首先，謝謝你願意參與這場活動！")
  print("以下將開始這次的活動，你只需要放鬆進行就可以！")

  #詢問性別(目前版本只服務女性)
  gender = input("你的性別是？male or female:")
  if gender != "female":
    print("對不起! 目前配對器人只提供給女性使用")
  else:   
    print("一定是位大美女呢！")
    birth_year = int(input("你是出生在哪一年呢？西元幾年呢?:"))
    age = 2021-birth_year
    print(f"你今年{age}歲, 哇，看來是適婚年齡喲！")
    print("那您能接受對方的年紀是如何呢？")

    #對象的年紀偏好(有1到3可選擇,超出範圍可重選)--<<此為配對參考條件之一>>
    while True:
      mate_age_sel = int(input("（1）年紀比我大（2）年紀相同（3）年紀比我小? 請選擇一個號碼: "))
      if mate_age_sel == 1:
        mate1_age = age + 2
        mate2_age = age + 4
        mate3_age = age + 5
        mate4_age = age + 7
        print("不錯的選擇! 看來你需要一個值得信賴,會照顧你的人，哈哈。")
        break # 跳出迴圈
      elif mate_age_sel == 2:
        mate1_age = age 
        mate2_age = age
        mate3_age = age 
        mate4_age = age
        print("不錯的選擇! 看來你需要一個年紀相仿,能夠與你談心的人，哈哈。")
        break # 跳出迴圈
      elif mate_age_sel == 3:
        mate1_age = age - 1
        mate2_age = age - 2
        mate3_age = age - 4
        mate4_age = age - 5       
        print("不錯的選擇! 看來你想要來一場快樂的姐弟戀，哈哈。")
        break # 跳出迴圈
      else:
        print("沒有這個數字選擇喔, 請看清楚再選喲") 
    
    #小聊性格(有1到2可選擇,超出範圍可重選)
    while True:
      own_type = int(input("你的性格是屬於（1）女強人（2）小鳥依人型 ? 請選擇一個號碼:")) 
      if own_type == 1:
        print("哇！原來是女強人, 這和我所想的大不相同呢！")
        break # 跳出迴圈
      elif own_type == 2:
        print("喔！溫柔婉約, 小鳥依人, 和我猜想的差不多！")
        break # 跳出迴圈
      else:
        print("沒有這個數字選擇喔, 請看清楚再選喲")

    #是否要喝咖啡緩和一下情緒(有1到2可選擇,超出範圍可重選)
    print("看來您還有些緊張呢！")
    coffee_demand = input("是否喝杯咖啡放鬆一下呢？yes or no :")
    if coffee_demand == "yes":
      while True:
        coffee_type = int(input("我們桌上有兩種咖啡, (1)美式 或 (2)拿鐵 ,你要哪一種? 請選擇一個號碼:"))
        if coffee_type == 1:
          print("美式咖啡是左邊那一杯,我也蠻喜歡美式香純的口感呢！請享用吧!")
          break # 跳出迴圈
        elif coffee_type == 2:
          print("拿鐵咖啡是右邊那一杯,我也蠻喜歡拿鐵柔順的口感呢！請享用吧！")
          break # 跳出迴圈
        else:
          print("沒有這個數字選擇喔, 請看清楚再選喲")

    else:
      print("了解, 你現在不需要咖啡, 那麼我們繼續往下進行")

    #詢問星座
    star_sign = input("有點好奇你的星座是？:")
    print(f"原來是{star_sign}啊！")
    print("聽說這個星座的人都很溫柔呢~")
    print("你一定也是個很溫柔的人！")

    #詢問喜歡哪種身高的男生--<<此為配對參考條件之一>>
    boy_height = int(input("你喜歡男生多高呢？大約幾公分:"))

    #詢問平常喜歡哪種活動(有1到5可選擇,超出範圍可重選)--<<此為配對參考條件之一>>
    print("你平常空閒時較喜歡做什麼活動呢？")
    while True:
      activity_sel = int(input("(1)看電影 (2)健身 (3)逛街 (4)親近大自然 (5)閱讀 ,請選擇一個號碼: "))
      if activity_sel == 1:
        activity_type = "看電影"
        print(f"了解,{activity_type}是一個讓人刺激又放鬆的活動")
        break # 跳出迴圈
      elif activity_sel == 2:
        activity_type = "健身"
        print(f"了解,{activity_type}是一個讓人流汗與保持好身材的活動")
        break # 跳出迴圈
      elif activity_sel == 3:
        activity_type = "逛街"
        print(f"了解,{activity_type}是一個讓人有種尋寶與滿足購買慾的活動")
        break # 跳出迴圈
      elif activity_sel == 4:
        activity_type = "親近大自然"
        print(f"了解,{activity_type}是一個讓人心曠神怡的活動")
        break # 跳出迴圈  
      elif activity_sel == 5:
        activity_type = "閱讀"
        print(f"了解,{activity_type}是一個讓人與作者有心靈交流的活動")
        break # 跳出迴圈   
      else:
        print("沒有這個數字選擇喔, 請看清楚再選喲") 

    #開始進行測驗嗎?
    while True:
      go_next = input("接下來我們將進行一個測驗，準備好了嗎？yes or no:")
      if go_next == "yes":
        print("那我們開始囉！")
        break # 跳出迴圈
      else:
        print("放輕鬆...")

    #第一個問題(有1到3可選擇,超出範圍可重選)
    print("第一個問題:")
    print("你展開了新生活，並且獨自住在陌生的城市裡。你第一個發訊息的人會是誰呢？")
    while True:
      q1_answer = int(input("(1)父母 (2)戀人 (3)朋友 ,請選擇一個號碼: "))
      if q1_answer <= 3:
        print("OK")
        break # 跳出迴圈
      else:
        print("沒有這個數字選擇喔, 請看清楚再選喲")  
 
    #第二個問題(有1到4可選擇,超出範圍可重選)
    print("接下來是第二個問題:")
    print("在夢裡，你喜歡的人有一部的身體消失了，你認為是哪裡？")
    while True:
      q2_answer = int(input("(1)眼睛 (2)手 (3)腳 (4)心臟 ,請選擇一個號碼: "))
      if q2_answer <= 4:
        print("OK")
        break # 跳出迴圈
      else:
        print("沒有這個數字選擇喔, 請看清楚再選喲")

    #最後一個問題(有1到3可選擇,超出範圍可重選)
    print("最後一個問題囉:")
    print("你去了遊樂園，通常會最先玩什麼遊戲？")
    while True:
      q3_answer = int(input("(1)摩天輪 (2)雲霄飛車 (3)旋轉木馬 ,請選擇一個號碼: "))
      if q3_answer <= 3:
        print("OK")
        break # 跳出迴圈
      else:
        print("沒有這個數字選擇喔, 請看清楚再選喲")  
    
    #測驗的簡單解答
    print("恭喜你做完這個小測驗！")       
    print("現在就來向你解答這個小測驗的結果囉！")
    print("你在感情中是個黏人很黏人的另一半哦！")
    print("在戀愛中的佔有慾也很強，有時候會吃醋~")
    print("透過這個測驗我也鎖定了一些適合你的另一半！")
    print("符合你的條件是")

    #依照活動類型,年紀及身高偏好,產生以下配對結果提供選擇
    print(f"(1)喜愛{activity_type}/雙子座/{mate1_age}歲/身高{boy_height+1}公分，陳先生")
    print(f"(2)喜愛{activity_type}/金牛座/{mate2_age}歲/身高{boy_height-1}公分，張先生")
    print(f"(3)喜愛{activity_type}/雙魚座/{mate3_age}歲/身高{boy_height}公分，蔡先生")
    print(f"(4)喜愛{activity_type}/摩羯座/{mate4_age}歲/身高{boy_height+2}公分，林先生")

    #以上四位配對結果,請從中選擇一個想約會的對象(有1到4可選擇,超出範圍可重選)
    while True:
      mate_sel = int(input("以上四位配對結果,請選擇一個號碼: "))
      if mate_sel == 1:
        print("哇！配對結果出來了！馬上為您安排與陳先生一對一約會專案！")
        break # 跳出迴圈
      elif mate_sel == 2:
        print("哇！配對結果出來了！馬上為您安排與張先生一對一約會專案！")
        break # 跳出迴圈
      elif mate_sel == 3:
        print("哇！配對結果出來了！馬上為您安排與蔡先生一對一約會專案！")
        break # 跳出迴圈
      elif mate_sel == 4:
        print("哇！配對結果出來了！馬上為您安排與林先生一對一約會專案！")
        break # 跳出迴圈    
      else:
        print("沒有這個數字選擇喔,好對象是不等人的,請看清楚再選喲")

    #完成與祝福
    print("祝福您遇見真命天子！Bye-Bye")
# Out:
# 嗨！你好我是配對機器人,
# 在現今的社會中,大部分的人都忙碌於自己的工作或課業,沒有時間或機會找到自己的Mr.Right
# 如果你也有這方面的困擾,找我就對了!
# 首先,我想了解一個基本問題
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
# ...
